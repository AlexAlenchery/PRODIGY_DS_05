# %%
import csv
import pandas as pd
df = pd.read_csv('C:/Users/admin/Desktop/FullStackWebDevelopment/word_docs/accident_data.csv')
df
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    05-06-2019  51.506187
# 1       200701BS65737           Serious    02-07-2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight    03-09-2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
#Readjusting the date format. 
data['Accident Date'] = pd.to_datetime(data['Accident Date'], format='%d-%m-%Y')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check the structure and types of data.
print(df.info())

# Convert 'Accident Date' column to datetime format.
df['Accident Date'] = pd.to_datetime(df['Accident Date'])

# Create a heatmap to show accident hotspots.
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Longitude', y='Latitude', hue='Accident_Severity', data=data, palette='coolwarm')
plt.title('Accident Hotspots')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Accident Severity')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  datetime64[ns]
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %%
# Plotting accident hotspots using latitude and longitude
plt.figure(figsize=(10, 8))
plt.scatter(data['Longitude'], data['Latitude'], alpha=0.5, c='red')
plt.title('Accident Hotspots')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
# Plotting contributing factors: Light Conditions.
plt.figure(figsize=(10, 6))
sns.countplot(x='Light_Conditions', data=data, palette='muted')
plt.title('Accidents by Light Conditions')
plt.xlabel('Light Conditions')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Plotting contributing factors: Road Surface Conditions.
plt.figure(figsize=(10, 6))
sns.countplot(x='Road_Surface_Conditions', data=data, palette='pastel')
plt.title('Accidents by Road Surface Conditions')
plt.xlabel('Road Surface Conditions')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Plotting contributing factors: Weather Conditions.
plt.figure(figsize=(10, 6))
sns.countplot(x='Weather_Conditions', data=data, palette='dark')
plt.title('Accidents by Weather Conditions')
plt.xlabel('Weather Conditions')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1880\3773971829.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Light_Conditions', data=data, palette='muted')
# C:\Users\admin\AppData\Local\Temp\ipykernel_1880\3773971829.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Road_Surface_Conditions', data=data, palette='pastel')
# C:\Users\admin\AppData\Local\Temp\ipykernel_1880\3773971829.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Weather_Conditions', data=data, palette='dark')

# %%
# Data for accident severity distribution.
severity_count = df['Accident_Severity'].value_counts()

# Creating a pie chart.
plt.figure(figsize=(8, 8))
plt.pie(severity_count, labels=severity_count.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Accident Severity Distribution')
plt.show()

# %% [markdown]
# Inference:
# The generalisations and inferences that we can draw from this analysis is that majority accidents do take place in normal conditions such as fine weather with no high winds, daylight and dry road surfaces however the severity is much higher when unnatural conditions are involved such as rain and high winds, wet or snowy road surfaces and darkness or no lighting.
